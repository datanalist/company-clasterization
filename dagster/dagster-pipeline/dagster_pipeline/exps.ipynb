# %%
import pandas as pd

# %%
lenta = pd.read_csv(r"C:\Users\R1\Documents\Business\company-clasterization\data\raw\lenta-news.csv")
news = pd.read_csv(r"C:\Users\R1\Documents\Business\company-clasterization\data\raw\news.csv")

df = pd.concat([lenta, news])

df.to_csv(r"C:\Users\R1\Documents\Business\company-clasterization\data\raw\nnews.csv", index=False)

# %%
df.shape
# Out:
# (1905, 4)

# %%
lenta.shape, news.shape
# Out:
# ((15, 4), (1890, 2))
