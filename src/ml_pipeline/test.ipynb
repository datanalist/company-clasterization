# %%
from models import *

# %%
model = ReductionModel(method="svd", n_components=15)

# %%
model = ClusteringModel(model_name="agglomerative", n_clusters=10)

# %%
model = VectorizerModel(model_name="count")

# %%
type(model)
# Out:
# sentence_transformers.SentenceTransformer.SentenceTransformer

# %%
model =  EmbeddingModel(model_name="all-MiniLM-L6-v2")

# %%
model.encode("Hello, world!")
# Out:
# array([-3.81771363e-02,  3.29110250e-02, -5.45939663e-03,  1.43698929e-02,
#        -4.02909815e-02, -1.16532527e-01,  3.16875950e-02,  1.91169116e-03,
#        -4.26223129e-02,  2.91680712e-02,  4.24266644e-02,  3.20417434e-02,
#         2.98447125e-02,  1.09802857e-02, -5.39396815e-02, -5.02772629e-02,
#        -2.35078987e-02,  1.07794097e-02, -1.37707949e-01,  4.11506649e-03,
#         2.93330774e-02,  6.68411553e-02, -1.53894424e-02,  4.84376214e-02,
#        -8.81497040e-02, -1.27268247e-02,  4.14089859e-02,  4.08315174e-02,
#        -5.01559563e-02, -5.81250116e-02,  4.88015376e-02,  6.88900426e-02,
#         5.87469265e-02,  8.73097312e-03, -1.59182549e-02,  8.51420090e-02,
#        -7.81473741e-02, -7.75168017e-02,  2.07237992e-02,  1.61942858e-02,
#         3.25105786e-02, -5.34889027e-02, -6.22288063e-02, -2.43145712e-02,
#         7.41277123e-03,  2.39777099e-02,  6.36093877e-03,  5.11451252e-02,
# ...
